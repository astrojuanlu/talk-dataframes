# %%
import pyarrow as pa

pa.__version__
# Out:
# '7.0.0'

# %%
from pyarrow.csv import read_csv

nyc = read_csv("/data/nyc-taxi/yellow_tripdata_2015-01.csv")
len(nyc)
# Out:
# 12748986

# %%
nyc.schema
# Out:
# VendorID: int64
# tpep_pickup_datetime: timestamp[s]
# tpep_dropoff_datetime: timestamp[s]
# passenger_count: int64
# trip_distance: double
# pickup_longitude: double
# pickup_latitude: double
# RateCodeID: int64
# store_and_fwd_flag: string
# dropoff_longitude: double
# dropoff_latitude: double
# payment_type: int64
# fare_amount: double
# extra: double
# mta_tax: double
# tip_amount: double
# tolls_amount: double
# improvement_surcharge: double
# total_amount: double

# %%
print("RSS (RAM): {}MB".format(pa.total_allocated_bytes() >> 20))
# Out:
# RSS (RAM): 1812MB

# %%
nyc["trip_distance"]
# Out:
# ...
# [
#   [
#     1.59,
#     3.3,
#     1.8,
#     0.5,
#     3,
#     9,
#     2.2,
#     0.8,
#     18.2,
#     0.9,
#     ...
#     17.67,
#     0.81,
#     1.84,
#     6.77,
#     2.03,
#     1.6,
#     1.39,
#     9.6,
#     1.73,
#     6
#   ],
#   [
#     1.49,
#     1.53,
#     0.8,
#     4,
#     0.8,
#     2.1,
#     1.6,
#     0.8,
#     0.7,
#     3.3,
#     ...
#     1.96,
#     0.47,
#     0.94,
#     3.75,
#     1.34,
#     9.35,
#     1.31,
#     1.67,
#     2.22,
#     0.48
#   ],
#   [
#     14.39,
#     1.29,
#     3.11,
#     1.38,
#     0.92,
#     1.27,
#     1.37,
#     0.98,
#     0.99,
#     0.84,
#     ...
#     3.03,
#     0.46,
#     0.87,
#     0.78,
#     2.54,
#     1.53,
#     0.71,
#     0.87,
#     0.77,
#     2.85
#   ],
#   [
#     2.6,
#     4.09,
#     1.46,
#     5.33,
#     1.62,
#     5.45,
#     1.77,
#     0.97,
#     1.5,
#     2.08,
#     ...
#     2.53,
#     0.57,
#     2.55,
#     2.4,
#     7.5,
#     3.2,
#     1.2,
#     1.28,
#     0,
# ...

# %%
nyc.select(["trip_distance", "total_amount"])
# Out:
# pyarrow.Table
# trip_distance: double
# total_amount: double
# ----
# ...

# %%
nyc.slice(100, 3).to_pandas()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2015-01-26 12:41:09   2015-01-26 12:45:08                1
# 1         1  2015-01-26 12:41:09   2015-01-26 12:45:39                1
# 2         1  2015-01-26 12:41:10   2015-01-26 13:05:04                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0            0.5        -73.982811        40.745255           1
# 1            0.8        -73.991493        40.738937           1
# 2            1.1        -73.982391        40.757408           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.980042         40.752075             2
# 1                  N         -73.988594         40.730511             2
# 2                  N         -73.968620         40.761520             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          4.5    0.0      0.5        0.00           0.0
# ...

# %%
nyc.take([100, 101, 102]).to_pandas()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2015-01-26 12:41:09   2015-01-26 12:45:08                1
# 1         1  2015-01-26 12:41:09   2015-01-26 12:45:39                1
# 2         1  2015-01-26 12:41:10   2015-01-26 13:05:04                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0            0.5        -73.982811        40.745255           1
# 1            0.8        -73.991493        40.738937           1
# 2            1.1        -73.982391        40.757408           1
#
#   store_and_fwd_flag  dropoff_longitude  dropoff_latitude  payment_type  \
# 0                  N         -73.980042         40.752075             2
# 1                  N         -73.988594         40.730511             2
# 2                  N         -73.968620         40.761520             1
#
#    fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0          4.5    0.0      0.5        0.00           0.0
# ...

# %%
# nyc["trip_distance"] = 0  # Raises TypeError!

# %%
pa.concat_tables(
    [nyc.slice(1_000, 3), nyc.slice(2_000, 3)]
).to_pandas()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         1  2015-01-07 20:40:05   2015-01-07 20:45:40                1
# 1         1  2015-01-07 20:40:05   2015-01-07 20:43:41                1
# 2         1  2015-01-07 20:40:05   2015-01-07 20:53:31                1
# 3         2  2015-01-30 19:50:06   2015-01-30 19:57:28                1
# 4         1  2015-01-21 07:10:15   2015-01-21 07:17:05                1
# 5         1  2015-01-21 07:10:16   2015-01-21 07:19:41                1
#
#    trip_distance  pickup_longitude  pickup_latitude  RateCodeID  \
# 0           1.10        -73.995155        40.716038           1
# 1           0.70        -73.960281        40.766186           1
# 2           1.70        -73.967667        40.758720           1
# 3           1.69        -73.996536        40.737839           1
# 4           1.20        -73.975159        40.761135           1
# 5           2.20        -73.947067        40.771641           1
#
# ...
